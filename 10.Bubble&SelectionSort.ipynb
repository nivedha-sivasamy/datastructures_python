# %%
def main():


    def bubble_sort(arr):
        for i in range(len(arr)):
            for j in range(0,len(arr)-i-1):
                if arr[j]>arr[j+1]:
                    arr[j],arr[j+1]=arr[j+1],arr[j]
        print("The sorted array is :",arr,"\n")
        return

    def selection_sort(arr):
        n=len(arr)
        for i in range(n):
            minimum=i
            for j in range(i+1,n):
                if arr[j]<arr[minimum]:
                    minimum=j
            arr[i],arr[minimum]=arr[minimum],arr[i]
        print("The sorted array is :",arr,"\n")
        return

    def create_array():
        print("\nCreate an array\n")
        numbr=int(input("Enter the number of elements required :"))
        n=[]
        if numbr>0:
            for i in range(numbr):
                    num=r.randint(-100,100)
                    n.append(num)
            print("The array is :",n,"\n")
        else:
            print("Inavlid Range entered")
        return n

    import random as r
    import numpy as np


    print("Sort Algorithm")
    try:
        while True:
            print("\n*************************")
            print("\nThe choices are:")
            print("1.Bubble Sort")
            print("2.Selection Sort")
            print("3.Exit")
            choice=input("Your Choice: ")

            if choice=='1':
                print("\n*************************")
                print("\nBubble Sort\n")
                n1=create_array()
                bubble_sort(n1)
                print("\n*************************")

            elif choice=='2':
                print("\n*************************")
                print("\nSelection Sort\n")
                n1=create_array()
                selection_sort(n1)
                print("\n*************************")

            elif choice=='3':
                print("END")
                break

            else:
                print("Invalid choice")
    except:
        print("!!!!!!!!!!Something is Wrong!!!!!!!!!!!!!")

# %%
main()
# Out:
# Sort Algorithm
#
# *************************
#
# The choices are:
# 1.Bubble Sort
# 2.Selection Sort
# 3.Exit
# Your Choice: 10
# Invalid choice
#
# *************************
#
# The choices are:
# 1.Bubble Sort
# 2.Selection Sort
# 3.Exit
# Your Choice: 1
#
# *************************
#
# Bubble Sort
#
#
# Create a array
#
# Enter the number of elements required :10
# The array is : [-28, -47, -11, 34, -50, -31, 13, 58, -76, -64]
#
# The sorted array is : [-76, -64, -50, -47, -31, -28, -11, 13, 34, 58]
#
#
# *************************
#
# *************************
#
# The choices are:
# 1.Bubble Sort
# 2.Selection Sort
# 3.Exit
# Your Choice: 2
#
# *************************
#
# Selection Sort
#
#
# Create a array
#
# Enter the number of elements required :20
# The array is : [-27, 35, -87, -71, 90, -23, 81, -74, -78, -71, -4, 11, 46, 27, 24, -67, -41, -8, 77, 20]
#
# The sorted array is : [-87, -78, -74, -71, -71, -67, -41, -27, -23, -8, -4, 11, 20, 24, 27, 35, 46, 77, 81, 90]
#
#
# *************************
#
# *************************
#
# The choices are:
# 1.Bubble Sort
# 2.Selection Sort
# 3.Exit
# Your Choice: 3
# END
